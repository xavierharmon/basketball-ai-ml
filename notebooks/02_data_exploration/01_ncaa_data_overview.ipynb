# %% [markdown]
# # NCAA Basketball Data Exploration
#
# This notebook downloads and explores NCAA basketball data from various sources including KenPom, game results, and team statistics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

print("NCAA Basketball Data Exploration")
print("=" * 50)
print("\nData sources to explore:")
print("1. Game schedules and results (Kaggle)")
print("2. KenPom ratings (multiple years)")
print("3. Team statistics and rankings")
print("4. March Madness tournament data")
print("5. NIL (Name, Image, Likeness) data")

# %% [markdown]
# ## Data Acquisition
#
# Recommended datasets from Kaggle:
#
# 1. **NCAA Regular Season Basketball Games** - 2011 to current
# 2. **KenPom Ratings 2025** - Includes historical ratings
# 3. **March Madness Historical Dataset** - 2002 to 2026
# 4. **College Basketball Dataset** - Comprehensive historical data
#
# To download:
# 1. Visit https://www.kaggle.com/
# 2. Create an account (or login)
# 3. Download datasets to `../data/ncaa_basketball/raw/`

# %%
# Template for loading data once downloaded

# Example: Load NCAA games data
# games = pd.read_csv('../data/ncaa_basketball/raw/games.csv')
# print(f"Games dataset shape: {games.shape}")
# print(games.head())

# Example: Load KenPom data
# kenpom = pd.read_csv('../data/kenpom/kenpom_ratings_2025.csv')
# print(f"KenPom shape: {kenpom.shape}")
# print(kenpom.head())

print("Ready to load data once downloaded from Kaggle!")

# %% [markdown]
# ## Data Exploration Templates
#
# Once data is loaded, use these templates to explore:

# %%
# Template: Basic statistics
# print(games.describe())
# print(games.info())

# Template: Missing values
# print(games.isnull().sum())

# Template: Team analysis
# team_stats = games.groupby('team').agg({'points': 'mean', 'wins': 'sum'})
# print(team_stats.sort_values('points', ascending=False).head(10))

# Template: Visualization
# plt.figure(figsize=(12, 6))
# plt.hist(games['points'], bins=30)
# plt.xlabel('Points Scored')
# plt.ylabel('Frequency')
# plt.title('Distribution of Team Points')
# plt.show()

print("Data exploration templates ready for use!")
